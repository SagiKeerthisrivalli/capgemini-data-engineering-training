# %%
# Correct path format for Unity Catalog Volumes:
# /Volumes/<catalog>/<schema>/<volume>/<path_to_file>
# Example: /Volumes/workspace/default/raw_data/orders.csv

df = spark.read.csv("/Volumes/workspace/default/raw_data/Iris.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.option("header",True).option("inferschema",True).csv("/Volumes/workspace/default/raw_data/Iris.csv")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Id: integer (nullable = true)
#  |-- SepalLengthCm: double (nullable = true)
#  |-- SepalWidthCm: double (nullable = true)
#  |-- PetalLengthCm: double (nullable = true)
#  |-- PetalWidthCm: double (nullable = true)
#  |-- Species: string (nullable = true)

# %%
s=df.distinct()
s.count()
# Out:
# 150

# %%
q = spark.read.csv(
    "/Volumes/workspace/default/raw_data/Iris.csv",
    header=True,
    inferSchema=True
)
display(q)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df=spark.sql("select * from default.airlines",headings=True,schema=True)
df.show()
# Out:
# +---------+--------------------+
# |IATA_CODE|             AIRLINE|
# +---------+--------------------+
# |       UA|United Air Lines ...|
# |       AA|American Airlines...|
# |       US|     US Airways Inc.|
# |       F9|Frontier Airlines...|
# |       B6|     JetBlue Airways|
# |       OO|Skywest Airlines ...|
# |       AS|Alaska Airlines Inc.|
# |       NK|    Spirit Air Lines|
# |       WN|Southwest Airline...|
# |       DL|Delta Air Lines Inc.|
# |       EV|Atlantic Southeas...|
# |       HA|Hawaiian Airlines...|
# |       MQ|American Eagle Ai...|
# |       VX|      Virgin America|
# +---------+--------------------+

# %%
# %sql
select * from default.airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
drop view airplane
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df.createTempView("airplane")

# %%
df.withColumnRenamed("IATA_CODE"," ID").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import*

# %%
df.withColumn("ID",lit("True")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE</th><th>AIRLINE</th></tr></thead><tbody><tr><td>UA</td><td>United Air Lines Inc.</td></tr><tr><td>AA</td><td>American Airlines Inc.</td></tr><tr><td>US</td><td>US Airways Inc.</td></tr><tr><td>F9</td><td>Frontier Airlines Inc.</td></tr><tr><td>B6</td><td>JetBlue Airways</td></tr><tr><td>OO</td><td>Skywest Airlines Inc.</td></tr><tr><td>AS</td><td>Alaska Airlines Inc.</td></tr><tr><td>NK</td><td>Spirit Air Lines</td></tr><tr><td>WN</td><td>Southwest Airlines Co.</td></tr><tr><td>DL</td><td>Delta Air Lines Inc.</td></tr></tbody></table></div>

# %%
df.drop("IATA_CODE").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE</th></tr></thead><tbody><tr><td>United Air Lines Inc.</td></tr><tr><td>American Airlines Inc.</td></tr><tr><td>US Airways Inc.</td></tr><tr><td>Frontier Airlines Inc.</td></tr><tr><td>JetBlue Airways</td></tr><tr><td>Skywest Airlines Inc.</td></tr><tr><td>Alaska Airlines Inc.</td></tr><tr><td>Spirit Air Lines</td></tr><tr><td>Southwest Airlines Co.</td></tr><tr><td>Delta Air Lines Inc.</td></tr><tr><td>Atlantic Southeast Airlines</td></tr><tr><td>Hawaiian Airlines Inc.</td></tr><tr><td>American Eagle Airlines Inc.</td></tr><tr><td>Virgin America</td></tr></tbody></table></div>

# %%
df.dropDuplicates().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.dropDuplicates(["IATA_CODE"]).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.distinct().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data1=[("1","keerthi"),("2","srivalli")]
schema1 = ["Id", "Name"]
df1 = spark.createDataFrame(data1,schema1)
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Name</th></tr></thead><tbody><tr><td>1</td><td>keerthi</td></tr><tr><td>2</td><td>srivalli</td></tr></tbody></table></div>

# %%
data2=[("3","babu"),("4","Phani")]
schema2=["Id","Name"]

df2 = spark.createDataFrame(data2,schema2)
df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Name</th></tr></thead><tbody><tr><td>3</td><td>babu</td></tr><tr><td>4</td><td>Phani</td></tr></tbody></table></div>

# %%
df1.union(df2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Name</th></tr></thead><tbody><tr><td>1</td><td>keerthi</td></tr><tr><td>2</td><td>srivalli</td></tr><tr><td>3</td><td>babu</td></tr><tr><td>4</td><td>Phani</td></tr></tbody></table></div>

# %%
df1.unionByName(df2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Name</th></tr></thead><tbody><tr><td>1</td><td>keerthi</td></tr><tr><td>2</td><td>srivalli</td></tr><tr><td>3</td><td>babu</td></tr><tr><td>4</td><td>Phani</td></tr></tbody></table></div>

# %%
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_csv = df.withColumn("Curr_Date", current_date())
df_csv.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_csv = df_csv.withColumn("WeekAfter",date_add("Curr_Date",7))
df_csv.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_csv.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_csv.dropna("any").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_csv.dropna("all").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
data = [
    ("user1","book1"),
    ("user1","book2"),
    ("user2","book2"),
    ("user2","book4"),
    ("user3","book1")
]
schema = ["user","book"]
df_book = spark.createDataFrame(data,schema)
df_book.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>book</th></tr></thead><tbody><tr><td>user1</td><td>book1</td></tr><tr><td>user1</td><td>book2</td></tr><tr><td>user2</td><td>book2</td></tr><tr><td>user2</td><td>book4</td></tr><tr><td>user3</td><td>book1</td></tr></tbody></table></div>

# %%
df_book.groupBy("user").agg(collect_list("book")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>collect_list(book)</th></tr></thead><tbody><tr><td>user1</td><td>List(book1, book2)</td></tr><tr><td>user2</td><td>List(book2, book4)</td></tr><tr><td>user3</td><td>List(book1)</td></tr></tbody></table></div>
